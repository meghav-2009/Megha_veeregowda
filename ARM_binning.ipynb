# %%
import pandas as pd

# %%
df = pd.read_csv("Cleaned_DS.csv")
df
# Out:
#      device_brand       os  screen_size   4g   5g  rear_camera_mp  \
# 0           Honor  Android        14.50  yes   no            13.0
# 1           Honor  Android        17.30  yes  yes            13.0
# 2           Honor  Android        16.69  yes  yes            13.0
# 3           Honor  Android        25.50  yes  yes            13.0
# 4           Honor  Android        15.32  yes   no            13.0
# ...           ...      ...          ...  ...  ...             ...
# 3449         Asus  Android        15.34  yes   no             NaN
# 3450         Asus  Android        15.24  yes   no            13.0
# 3451      Alcatel  Android        15.80  yes   no            13.0
# 3452      Alcatel  Android        15.80  yes   no            13.0
# 3453      Alcatel  Android        12.83  yes   no            13.0
#
#       front_camera_mp  internal_memory  ram  battery  weight  release_year  \
# 0                 5.0             64.0  3.0   3020.0   146.0          2020
# ...

# %%
# extract specific columns by name
arm_df = df[["device_brand", "os", "screen_size","front_camera_mp","release_year"]]

# %%
arm_df.isnull().sum()
# Out:
# device_brand       0
# os                 0
# screen_size        0
# front_camera_mp    2
# release_year       0
# dtype: int64

# %%
df = arm_df.dropna()

# %%
df.isnull().sum()
# Out:
# device_brand       0
# os                 0
# screen_size        0
# front_camera_mp    0
# release_year       0
# dtype: int64

# %%
df.to_csv("ARM_dataset.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8760\1593928681.py in <module>
# ----> 1 df.to_csv("ARM_dataset.csv", index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ...

# %%
new_df = pd.read_csv("ARM_dataset.csv")

new_df
# Out:
#      device_brand       os  screen_size  front_camera_mp  release_year
# 0           Honor  Android        14.50              5.0          2020
# 1           Honor  Android        17.30             16.0          2020
# 2           Honor  Android        16.69              8.0          2020
# 3           Honor  Android        25.50              8.0          2020
# 4           Honor  Android        15.32              8.0          2020
# ...           ...      ...          ...              ...           ...
# 3447         Asus  Android        15.34              8.0          2019
# 3448         Asus  Android        15.24              8.0          2018
# 3449      Alcatel  Android        15.80              5.0          2020
# 3450      Alcatel  Android        15.80              5.0          2020
# 3451      Alcatel  Android        12.83              5.0          2020
#
# [3452 rows x 5 columns]

# %%
df=new_df

# %%
import pandas as pd

# Load dataset


# Define custom categories for screen_size column
screen_size_categories = ['small', 'medium', 'large', 'extra-large']
screen_size_bins = [0, 5, 10, 15, 35]
df['screen_size_bin'] = pd.cut(df['screen_size'], bins=screen_size_bins, labels=screen_size_categories)

# Define custom categories for front_column column
front_column_categories = ['short', 'medium', 'long', 'extra-long']
front_column_bins = [0, 10, 20, 30, 35]
df['front_camera_bin'] = pd.cut(df['front_camera_mp'], bins=front_column_bins, labels=front_column_categories)

# Create a new column for release year label
df['release_year_label'] = df['release_year'].apply(lambda x: 'year_' + str(x))

# Select columns to use for association rule mining
transactions = df[['screen_size_bin', 'front_camera_bin', 'release_year_label']]

# Convert to list of lists format
transactions_list = transactions.values.tolist()

# %%
df.drop(columns=['screen_size', 'front_camera_mp', 'release_year'], inplace=True)

# %%
df
# Out:
#      device_brand       os screen_size_bin front_camera_bin release_year_label
# 0           Honor  Android           large            short          year_2020
# 1           Honor  Android     extra-large           medium          year_2020
# 2           Honor  Android     extra-large            short          year_2020
# 3           Honor  Android     extra-large            short          year_2020
# 4           Honor  Android     extra-large            short          year_2020
# ...           ...      ...             ...              ...                ...
# 3447         Asus  Android     extra-large            short          year_2019
# 3448         Asus  Android     extra-large            short          year_2018
# 3449      Alcatel  Android     extra-large            short          year_2020
# 3450      Alcatel  Android     extra-large            short          year_2020
# 3451      Alcatel  Android           large            short          year_2020
#
# [3452 rows x 5 columns]

# %%
transactions_list
# Out:
# [['large', 'short', 'year_2020'],
#  ['extra-large', 'medium', 'year_2020'],
#  ['extra-large', 'short', 'year_2020'],
#  ['extra-large', 'short', 'year_2020'],
#  ['extra-large', 'short', 'year_2020'],
#  ['extra-large', 'short', 'year_2020'],
#  ['large', 'short', 'year_2020'],
#  ['extra-large', 'short', 'year_2020'],
#  ['extra-large', 'medium', 'year_2020'],
#  ['extra-large', 'short', 'year_2020'],
#  ['extra-large', 'short', 'year_2020'],
#  ['extra-large', 'short', 'year_2020'],
#  ['extra-large', 'medium', 'year_2019'],
#  ['extra-large', 'medium', 'year_2019'],
#  ['large', 'short', 'year_2019'],
#  ['extra-large', 'short', 'year_2019'],
#  ['extra-large', 'extra-long', 'year_2019'],
#  ['extra-large', 'medium', 'year_2019'],
#  ['large', 'short', 'year_2019'],
#  ['extra-large', 'short', 'year_2019'],
#  ['extra-large', 'short', 'year_2019'],
#  ['extra-large', 'short', 'year_2013'],
#  ['extra-large', 'medium', 'year_2019'],
#  ['large', 'medium', 'year_2019'],
# ...

# %%
import csv

# Save transaction list as CSV file
with open('transactions.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(transactions_list)
