# %%
import pandas as pd

# %%
df1 = pd.read_csv("Cleaned_DS.csv")

# %%
df2 = pd.read_csv("Decision_tree.csv")

# %%
merge_df = pd.merge(df1,df2)
df = merge_df.drop(columns=["Unnamed: 0"])

# %%
df
# Out:
#      device_brand       os  screen_size   4g   5g  rear_camera_mp  \
# 0           Honor  Android        14.50  yes   no            13.0
# 1           Honor  Android        17.30  yes  yes            13.0
# 2           Honor  Android        16.69  yes  yes            13.0
# 3           Honor  Android        25.50  yes  yes            13.0
# 4           Honor  Android        15.32  yes   no            13.0
# ...           ...      ...          ...  ...  ...             ...
# 3322        Apple      iOS        12.90  yes   no             8.0
# 3323         Asus  Android        15.24  yes   no            13.0
# 3324      Alcatel  Android        15.80  yes   no            13.0
# 3325      Alcatel  Android        15.80  yes   no            13.0
# 3326      Alcatel  Android        12.83  yes   no            13.0
#
#       front_camera_mp  internal_memory  ram  battery  weight  release_year  \
# 0                 5.0             64.0  3.0   3020.0   146.0          2020
# ...

# %%
df = df.drop(columns=[ "internal_memory_binned", "front_camera_mp_binned","release_year_binned","normalized_new_price","used_price","os","device_brand","4g","5g"])

# %%
df
# Out:
#       screen_size  rear_camera_mp  front_camera_mp  internal_memory  ram  \
# 0           14.50            13.0              5.0             64.0  3.0
# 1           17.30            13.0             16.0            128.0  8.0
# 2           16.69            13.0              8.0            128.0  8.0
# 3           25.50            13.0              8.0             64.0  6.0
# 4           15.32            13.0              8.0             64.0  3.0
# ...           ...             ...              ...              ...  ...
# 3322        12.90             8.0              7.0             64.0  4.0
# 3323        15.24            13.0              8.0            128.0  8.0
# 3324        15.80            13.0              5.0             32.0  3.0
# 3325        15.80            13.0              5.0             32.0  2.0
# 3326        12.83            13.0              5.0             16.0  2.0
#
#       battery  weight  release_year  days_used  normalized_used_price  \
# ...

# %%
df.isnull().sum()
# Out:
# screen_size              0
# rear_camera_mp           9
# front_camera_mp          0
# internal_memory          0
# ram                      0
# battery                  1
# weight                   1
# release_year             0
# days_used                0
# normalized_used_price    0
# new_price                0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# screen_size              0
# rear_camera_mp           0
# front_camera_mp          0
# internal_memory          0
# ram                      0
# battery                  0
# weight                   0
# release_year             0
# days_used                0
# normalized_used_price    0
# new_price                0
# dtype: int64

# %%
df.to_csv("Cleaned_Dataset.csv")
